# %% [markdown]
# <a href="https://colab.research.google.com/github/beneditomacedo/dl_notebooks/blob/master/NumpyStack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numpy Stack
#
# available at https://www.udemy.com/course/numpy-python/learn/lecture/19425054

# %% [markdown]
# ## Section 2 - Numpy

# %% [markdown]
# ### 2.4 - Array vs Lists

# %%
import numpy as np

# %%
L = [1,2,3]
A = np.array([1,2,3])

# %%
for e in L:
  print(e)
# Out:
# 1
# 2
# 3

# %%
for e in A:
  print(e)
# Out:
# 1
# 2
# 3

# %%
type(A)
# Out:
# numpy.ndarray

# %%
print(A.shape)
# Out:
# (3,)

# %% [markdown]
# #### Appending list and numpy array
# python list has append method that increases the size of list but numpy array (ndarray) does not have this feature because of memory optimization.
# <br>
# source: https://numpy.org/devdocs/user/whatisnumpy.html#:~:text=NumPy%20arrays%20have%20a%20fixed,the%20same%20size%20in%20memory.

# %%
L.append(4)
print(L)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# A.append(4)
#
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-a17c4d6940c3> in <module>()
# ----> 1 A.append(4)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %% [markdown]
# #### how the list and numpy array handles operators + and *

# %%
#
print(f'original list -> {L}, after add [5] -> {L + [5]}')
# Out:
# original list -> [1, 2, 3], after add [5] -> [1, 2, 3, 5]

# %%
# this numpy array feature is called broadcasting
#
print(f'original array -> {A}, after add [5] -> {A + [5]}')
# Out:
# original array -> [1 2 3], after add [5] -> [6 7 8]

# %%
A + [5]
# Out:
# array([6, 7, 8])

# %%
print(f'original list -> {L}, list multiplied by 2 -> {L * 2}')
# Out:
# original list -> [1, 2, 3], list multiplied by 2 -> [1, 2, 3, 1, 2, 3]

# %%
print(f'original array -> {A}, array multiplied by 2 -> {A * 2}')
# Out:
# original array -> [1 2 3], array multiplied by 2 -> [2 4 6]

# %% [markdown]
# #### Multiplying a list by a scalar

# %%
# using for loop
#
L2 = []
scalar = 2

for e in L:
  L2.append(e * scalar)

print(f'original list -> {L}, multiplied by 2 -> {L2}')
# Out:
# original list -> [1, 2, 3], multiplied by 2 -> [2, 4, 6]

# %%
# using list comprehension
#
L2 = [e * scalar for e in L]
print(f'original list -> {L}, multiplied by 2 -> {L2}')
# Out:
# original list -> [1, 2, 3], multiplied by 2 -> [2, 4, 6]

# %% [markdown]
# #### numpy almost always operates element wise

# %%
print(A)
# Out:
# [1 2 3]

# %%
np.sqrt(A)
# Out:
# array([1.        , 1.41421356, 1.73205081])

# %%
np.log(A)
# Out:
# array([0.        , 0.69314718, 1.09861229])

# %%
np.exp(A)
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692])

# %%
np.tanh(A)
# Out:
# array([0.76159416, 0.96402758, 0.99505475])

# %% [markdown]
# ### 2.5 - Dot Product

# %%
a = np.array([1,2])
b = np.array([3,4])

# %%
dot = 0
for e, f in zip(a,b):
  dot += e * f
dot
# Out:
# 11

# %%
dot = 0
for i in range(len(a)):
  dot += a[i] * b[i]
dot
# Out:
# 11

# %%
a * b
# Out:
# array([3, 8])

# %%
np.sum(a*b)
# Out:
# 11

# %%
(a*b).sum()
# Out:
# 11

# %%
np.dot(a,b)
# Out:
# 11

# %%
a.dot(b)
# Out:
# 11

# %%
a @ b
# Out:
# 11

# %% [markdown]
# ![dot_product.png](data:image/png;base64,...)

# %%
# calculate the a magnitude
#
amag = np.sqrt((a*a).sum())
amag
# Out:
# 2.23606797749979

# %%
np.linalg.norm(a)
# Out:
# 2.23606797749979

# %%
cosangleAB = np.dot(a,b)/(np.linalg.norm(a)*np.linalg.norm(b))
cosangleAB
# Out:
# 0.9838699100999074

# %%
angle = np.arccos(cosangleAB)
angle
# Out:
# 0.17985349979247847

# %% [markdown]
# ### 2.5 Speed Test

# %%
from datetime import datetime

# %%
a = np.random.randn(100)
b = np.random.randn(100)
T = 100000

# %%
def slow_dot_product(a,b):
  result = 0
  for e,f in zip (a,b):
    result += e * f
  return result

# %%
t0 = datetime.now()
for t in range(T):
  slow_dot_product(a,b)
dt1 = datetime.now() - t0

t0 = datetime.now()
for t in range(T):
  a.dot(b)
dt2 = datetime.now() - t0
print(f'dt1/dt2 = {dt1.total_seconds()/dt2.total_seconds()}')
# Out:
# dt1/dt2 = 65.79358839488401

# %% [markdown]
# ### 2.7 Matrices

# %%
L = [[1,2],[3,4]]
L
# Out:
# [[1, 2], [3, 4]]

# %%
print (f'Row 0 -> {L[0]}')
# Out:
# Row 0 -> [1, 2]

# %%
print (f'Row 0 Column 1 -> {L[0][1]}')
# Out:
# Row 0 Column 1 -> 2

# %%
A = np.array([[1,2],[3,4]])
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
print (f'Row 0 -> {A[0]}')
# Out:
# Row 0 -> [1 2]

# %%
print (f'Row 0 Column 1 -> {A[0][1]}')
# Out:
# Row 0 Column 1 -> 2

# %%
print (f'Row 0 Column 1 -> {A[0,1]}')
# Out:
# Row 0 Column 1 -> 2

# %%
print (f'Column 1 -> {A[:,1]}')
# Out:
# Column 1 -> [2 4]

# %%
print (f'A \n{A}\nA.T \n{A.T}')
# Out:
# A
# [[1 2]
#  [3 4]]
# A.T
# [[1 3]
#  [2 4]]

# %%
print (f'A \n{np.exp(A)}\nL \n{np.exp(L)}')
# Out:
# A
# [[ 2.71828183  7.3890561 ]
#  [20.08553692 54.59815003]]
# L
# [[ 2.71828183  7.3890561 ]
#  [20.08553692 54.59815003]]

# %%
B = np.array([[1,2,3],[4,5,6]])
B
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
print (f'B {B.shape}\n{B}\n\nB.T {B.T.shape}\n{B.T}')
# Out:
# B (2, 3)
# [[1 2 3]
#  [4 5 6]]
#
# B.T (3, 2)
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
print (f'A {A.shape}\n{A}\n\nB {B.shape}\n{B}\n\nA dot B\n {A.dot(B)}')
# Out:
# A (2, 2)
# [[1 2]
#  [3 4]]
#
# B (2, 3)
# [[1 2 3]
#  [4 5 6]]
#
# A dot B
#  [[ 9 12 15]
#  [19 26 33]]

# %%
print (f'A \n{A}\n\ndet(A) {np.linalg.det(A)}')
# Out:
# A
# [[1 2]
#  [3 4]]
#
# det(A) -2.0000000000000004

# %%
print (f'A \n{A}\n\nA inv {np.linalg.inv(A)} \n\n {np.linalg.inv(A).dot(A)}')
# Out:
# A
# [[1 2]
#  [3 4]]
#
# A inv [[-2.   1. ]
#  [ 1.5 -0.5]]
#
#  [[1.00000000e+00 0.00000000e+00]
#  [1.11022302e-16 1.00000000e+00]]

# %%
# trace is the sum of diagonal
#
print (f'A \n{A}\n\ntrace(A) {np.trace(A)}')
# Out:
# A
# [[1 2]
#  [3 4]]
#
# trace(A) 5

# %%
print (f'A \n{A}\n\ndiag(A) {np.diag(A)}')
# Out:
# A
# [[1 2]
#  [3 4]]
#
# diag(A) [1 4]

# %%
np.diag([1,4])
# Out:
# array([[1, 0],
#        [0, 4]])

# %%
np.linalg.eig(A)
# Out:
# (array([-0.37228132,  5.37228132]), array([[-0.82456484, -0.41597356],
#         [ 0.56576746, -0.90937671]]))

# %%
Lam, V = np.linalg.eig(A)
print (f'Lam \n{Lam}\n\nV \n{V}')
# Out:
# Lam
# [-0.37228132  5.37228132]
#
# V
# [[-0.82456484 -0.41597356]
#  [ 0.56576746 -0.90937671]]

# %%
V[:,0] * Lam[0] == A @ V[:,0]
# Out:
# array([ True, False])

# %%
# the vector are not "equals" because of precision
#
V[:,0] * Lam[0] , A @ V[:,0]
# Out:
# (array([ 0.30697009, -0.21062466]), array([ 0.30697009, -0.21062466]))

# %%
np.allclose(V[:,0] * Lam[0] , A @ V[:,0])
# Out:
# True

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# ### 2.8 Solving Linear Systems

# %%
A = np.array([[1,1],[1.5,4]])
A
# Out:
# array([[1. , 1. ],
#        [1.5, 4. ]])

# %%
B = np.array([2200,5050])
B
# Out:
# array([2200, 5050])

# %%
# "inverse" is slower and less accurate
#
np.linalg.inv(A).dot(B)
# Out:
# array([1500.,  700.])

# %%
np.linalg.solve(A,B)
# Out:
# array([1500.,  700.])

# %% [markdown]
# ## Section 3 - Matplotlib

# %% [markdown]
# ### 2.12 Line chart

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,20,1000)

# %%
y = np.sin(x) + 0.2 * x

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.title('my plot')
# Out:
# Text(0.5, 1.0, 'my plot')

# %%
# look at ; at end of last command to remove the Text Stuff before the graph
#
plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.title('my plot');

# %% [markdown]
# ### 2.13 Scatterplot

# %%
X = np.random.randn(100,2)

# %%
plt.scatter(X[:,0],X[:,1]);

# %%
X = np.random.randn(200,2)
X[:50] += 3
Y = np.zeros(200)
Y[:50] = 1
plt.scatter(X[:,0],X[:,1],c=Y)

# %% [markdown]
# ### 2.14 Histogram

# %%
# normal distribution
#
X = np.random.randn(10000)

# %%
plt.hist(X);

# %%
plt.hist(X,bins=50);

# %%
# uniform distribution
#
X = np.random.random(10000)
plt.hist(X,bins=50);

# %% [markdown]
# ### 2.15 Plotting images

# %%
# !wget https://upload.wikimedia.org/wikipedia/en/thumb/7/7d/Lenna_%28test_image%29.png/440px-Lenna_%28test_image%29.png -O lena.png
# Out:
# --2020-09-29 02:00:25--  https://upload.wikimedia.org/wikipedia/en/thumb/7/7d/Lenna_%28test_image%29.png/440px-Lenna_%28test_image%29.png
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.154.240, 2620:0:861:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.154.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 342351 (334K) [image/png]
# Saving to: ‘lena.png’
#
# lena.png            100%[===================>] 334.33K  --.-KB/s    in 0.05s
#
# 2020-09-29 02:00:25 (5.95 MB/s) - ‘lena.png’ saved [342351/342351]

# %%
from PIL import Image

# %%
im = Image.open('lena.png')

# %%
type(im)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
arr = np.array(im)

# %%
arr.shape
# Out:
# (440, 440, 3)

# %%
arr.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(arr)

# %%
plt.imshow(im)

# %%
gray = arr.mean(axis=2)

# %%
arr[0,0]
# Out:
# array([226, 137, 124], dtype=uint8)

# %%
gray[0,0]
# Out:
# 162.33333333333334

# %%
gray.shape
# Out:
# (440, 440)

# %%
plt.imshow(gray);

# %%
plt.imshow(gray, cmap='gray');
